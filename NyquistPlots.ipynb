# %%
# %matplotlib widget
import control as ct # the standard library for basic operations for analysis and design of feedback control systems
import matplotlib.pyplot as plt # a comprehensive library for creating static, animated, and interactive visualizations
import numpy as np

# %%
s = ct.tf('s')
G = 1 / (s*(s+1)-3)
k = 1
L = G * k
plt.figure()
ct.nyquist_plot(L);
G
# Out:
# TransferFunction(array([1]), array([ 1,  1, -3]))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
G = (s-1)/ (s*(s+1))
k = 1
L = G * k
plt.figure()
ct.nyquist_plot(L);
G
# Out:
# TransferFunction(array([ 1, -1]), array([1, 1, 0]))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
G = (s-1)/ (s*(s+1)-3)
k = -1
L = G * k
plt.figure()
ct.nyquist_plot(L);
G
# Out:
# TransferFunction(array([ 1, -1]), array([ 1,  1, -3]))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
